# %%
# Project on Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\User\Downloads\train.csv')

# %%
df
# Out:
#                  PassengerId  Survived  Pclass  \
# 0                          1       0.0     3.0
# 1                          2       1.0     1.0
# 2                          3       1.0     3.0
# 3                          4       1.0     1.0
# 4                          5       0.0     3.0
# ..                       ...       ...     ...
# 889                      890       1.0     1.0
# 890                      891       0.0     3.0
# 891   this is another line.        NaN     NaN
# 892       Yet another line.        NaN     NaN
# 893              Final line.       NaN     NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         3
# Pclass           3
# Name             3
# Sex              3
# Age            180
# SibSp            3
# Parch            3
# Ticket           3
# Fare             3
# Cabin          690
# Embarked         5
# dtype: int64

# %%
# 1. Display total number of row
df.shape
# Out:
# (894, 12)

# %%
# 2. Display first 10 rows.
df.head(10)
# Out:
#   PassengerId  Survived  Pclass  \
# 0           1       0.0     3.0
# 1           2       1.0     1.0
# 2           3       1.0     3.0
# 3           4       1.0     1.0
# 4           5       0.0     3.0
# 5           6       0.0     3.0
# 6           7       0.0     1.0
# 7           8       0.0     3.0
# 8           9       1.0     3.0
# 9          10       1.0     2.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
# 5                                   Moran, Mr. James    male   NaN    0.0
# 6                            McCarthy, Mr. Timothy J    male  54.0    0.0
# ...

# %%
# 3. Display last 10 rows.
df.tail(10)
# Out:
#                  PassengerId  Survived  Pclass  \
# 884                      885       0.0     3.0
# 885                      886       0.0     3.0
# 886                      887       0.0     2.0
# 887                      888       1.0     1.0
# 888                      889       0.0     3.0
# 889                      890       1.0     1.0
# 890                      891       0.0     3.0
# 891   this is another line.        NaN     NaN
# 892       Yet another line.        NaN     NaN
# 893              Final line.       NaN     NaN
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 884                    Sutehall, Mr. Henry Jr    male  25.0    0.0    0.0
# 885      Rice, Mrs. William (Margaret Norton)  female  39.0    0.0    5.0
# 886                     Montvila, Rev. Juozas    male  27.0    0.0    0.0
# 887              Graham, Miss. Margaret Edith  female  19.0    0.0    0.0
# ...

# %%
# 4. Display all Column names.
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 5. Display random 10 rows.'
df.sample()
# Out:
#     PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 353         354       0.0     3.0  Arnold-Franchi, Mr. Josef  male  25.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 353    1.0    0.0  349237  17.8   NaN        S

# %%
# 6. Display rows from 100 to 125.
df.iloc[100:125]
# Out:
#     PassengerId  Survived  Pclass                               Name     Sex  \
# 100         101       0.0     3.0            Petranec, Miss. Matilda  female
# 101         102       0.0     3.0   Petroff, Mr. Pastcho ("Pentcho")    male
# 102         103       0.0     1.0          White, Mr. Richard Frasar    male
# 103         104       0.0     3.0         Johansson, Mr. Gustaf Joel    male
# 104         105       0.0     3.0     Gustafsson, Mr. Anders Vilhelm    male
# 105         106       0.0     3.0              Mionoff, Mr. Stoytcho    male
# 106         107       1.0     3.0   Salkjelsvik, Miss. Anna Kristine  female
# 107         108       1.0     3.0             Moss, Mr. Albert Johan    male
# 108         109       0.0     3.0                    Rekic, Mr. Tido    male
# 109         110       1.0     3.0                Moran, Miss. Bertha  female
# 110         111       0.0     1.0     Porter, Mr. Walter Chamberlain    male
# ...

# %%
# 7. Display Name, sex,age, survival status of passengers.
df[['PassengerId', 'Name', 'Sex', 'Age', 'Survived']]
# Out:
#                  PassengerId  \
# 0                          1
# 1                          2
# 2                          3
# 3                          4
# 4                          5
# ..                       ...
# 889                      890
# 890                      891
# 891   this is another line.
# 892       Yet another line.
# 893              Final line.
#
#                                                   Name     Sex   Age  Survived
# 0                              Braund, Mr. Owen Harris    male  22.0       0.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1.0
# 2                               Heikkinen, Miss. Laina  female  26.0       1.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1.0
# 4                             Allen, Mr. William Henry    male  35.0       0.0
# ..                                                 ...     ...   ...       ...
# ...

# %%
# 8. Display Name , age, sex of Males.
df[df.Sex == 'male'][['Name', 'Age', 'Sex']]
# Out:
#                                Name   Age   Sex
# 0           Braund, Mr. Owen Harris  22.0  male
# 4          Allen, Mr. William Henry  35.0  male
# 5                  Moran, Mr. James   NaN  male
# 6           McCarthy, Mr. Timothy J  54.0  male
# 7    Palsson, Master. Gosta Leonard   2.0  male
# ..                              ...   ...   ...
# 883   Banfield, Mr. Frederick James  28.0  male
# 884          Sutehall, Mr. Henry Jr  25.0  male
# 886           Montvila, Rev. Juozas  27.0  male
# 889           Behr, Mr. Karl Howell  26.0  male
# 890             Dooley, Mr. Patrick  32.0  male
#
# [577 rows x 3 columns]

# %%
# 9. Display Passengers traveling in first class.
df[df.Pclass == 1.0]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2       1.0     1.0
# 3             4       1.0     1.0
# 6             7       0.0     1.0
# 11           12       1.0     1.0
# 23           24       1.0     1.0
# ..          ...       ...     ...
# 871         872       1.0     1.0
# 872         873       0.0     1.0
# 879         880       1.0     1.0
# 887         888       1.0     1.0
# 889         890       1.0     1.0
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 6                              McCarthy, Mr. Timothy J    male  54.0    0.0
# 11                            Bonnell, Miss. Elizabeth  female  58.0    0.0
# 23                        Sloper, Mr. William Thompson    male  28.0    0.0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 10. Display average fare.
df['Fare'].mean().round(2)
# Out:
# np.float64(32.2)

# %%
# 11. Display Datatypes of all columns.
df.dtypes
# Out:
# PassengerId     object
# Survived       float64
# Pclass         float64
# Name            object
# Sex             object
# Age            float64
# SibSp          float64
# Parch          float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# 12. Display Continuous columns.
df.nunique()
cont = ['PassenegerId', 'Name', 'Age', 'Ticket', 'Fare', 'Cabin']

# %%
# 13. Display categorical columns.
df.nunique()
cat = ['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']

# %%
# 14. Display classes of each categorical columns.
df['Survived'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
for i in cat:
    print(i, df[i].unique())
# Out:
# Survived [ 0.  1. nan]
# Pclass [ 3.  1.  2. nan]
# Sex ['male' 'female' nan]
# SibSp [ 1.  0.  3.  4.  2.  5.  8. nan]
# Parch [ 0.  1.  2.  5.  3.  4.  6. nan]
# Embarked ['S' 'C' 'Q' nan 'Qn\\ This is being wrriten through append mode. ']

# %%
# 15. Display columns with null values.
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         3
# Pclass           3
# Name             3
# Sex              3
# Age            180
# SibSp            3
# Parch            3
# Ticket           3
# Fare             3
# Cabin          690
# Embarked         5
# dtype: int64

# %%
df
# Out:
#                  PassengerId  Survived  Pclass  \
# 0                          1       0.0     3.0
# 1                          2       1.0     1.0
# 2                          3       1.0     3.0
# 3                          4       1.0     1.0
# 4                          5       0.0     3.0
# ..                       ...       ...     ...
# 889                      890       1.0     1.0
# 890                      891       0.0     3.0
# 891   this is another line.        NaN     NaN
# 892       Yet another line.        NaN     NaN
# 893              Final line.       NaN     NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# ...

# %%
# 16. Display count of survived/non survived.  
df['Survived'].value_counts()
# Out:
# Survived
# 0.0    549
# 1.0    342
# Name: count, dtype: int64

# %%
# 17. Display count of male/females.
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# 18. Display count of passengers in each class.
df['Pclass'].value_counts()
# Out:
# Pclass
# 3.0    491
# 1.0    216
# 2.0    184
# Name: count, dtype: int64

# %%
# 19. Display count of each embarked.
df['Embarked'].value_counts()
# Out:
# Embarked
# S                                                  644
# C                                                  168
# Q                                                   76
# Qn\ This is being wrriten through append mode.       1
# Name: count, dtype: int64

# %%
# 20. Display mean , median of ages of passengers.
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].median()
# Out:
# np.float64(28.0)

# %%
df
# Out:
#                  PassengerId  Survived  Pclass  \
# 0                          1       0.0     3.0
# 1                          2       1.0     1.0
# 2                          3       1.0     3.0
# 3                          4       1.0     1.0
# 4                          5       0.0     3.0
# ..                       ...       ...     ...
# 889                      890       1.0     1.0
# 890                      891       0.0     3.0
# 891   this is another line.        NaN     NaN
# 892       Yet another line.        NaN     NaN
# 893              Final line.       NaN     NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# ...

# %%
# How many unique ticket numbers are there in the dataset?
df['Ticket'].value_counts()
# Out:
# Ticket
# 347082              7
# 1601                7
# CA. 2343            7
# 3101295             6
# CA 2144             6
#                    ..
# PC 17590            1
# 17463               1
# 330877              1
# 373450              1
# STON/O2. 3101282    1
# Name: count, Length: 681, dtype: int64

# %%
# Find the most expensive fare paid and the passenger(s) who paid it.
max_fare = df['Fare'].max()
passengers = df[df['Fare'] == max_fare]
print(max_fare, passengers)
# Out:
# 512.3292     PassengerId  Survived  Pclass                                Name     Sex  \
# 258         259       1.0     1.0                    Ward, Miss. Anna  female
# 679         680       1.0     1.0  Cardeza, Mr. Thomas Drake Martinez    male
# 737         738       1.0     1.0              Lesurer, Mr. Gustave J    male
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  35.0    0.0    0.0  PC 17755  512.3292          NaN        C
# 679  36.0    0.0    1.0  PC 17755  512.3292  B51 B53 B55        C
# 737  35.0    0.0    0.0  PC 17755  512.3292         B101        C

# %%
# Calculate the percentage of missing values in each column.
df.isnull().mean() * 100
# Out:
# PassengerId     0.000000
# Survived        0.335570
# Pclass          0.335570
# Name            0.335570
# Sex             0.335570
# Age            20.134228
# SibSp           0.335570
# Parch           0.335570
# Ticket          0.335570
# Fare            0.335570
# Cabin          77.181208
# Embarked        0.559284
# dtype: float64

# %%
# Create a new column family_size by adding sibsp (siblings/spouses) and parch (parents/children) together.

# Find the survival rate of passengers who traveled alone (family_size = 0).

# Find the probability of survival for passengers aged between 20 and 30.

# %%
# 21. Display names of all not survived passengers.
df[df.Survived == 0]['Name']
# Out:
# 0                       Braund, Mr. Owen Harris
# 4                      Allen, Mr. William Henry
# 5                              Moran, Mr. James
# 6                       McCarthy, Mr. Timothy J
# 7                Palsson, Master. Gosta Leonard
#                          ...
# 884                      Sutehall, Mr. Henry Jr
# 885        Rice, Mrs. William (Margaret Norton)
# 886                       Montvila, Rev. Juozas
# 888    Johnston, Miss. Catherine Helen "Carrie"
# 890                         Dooley, Mr. Patrick
# Name: Name, Length: 549, dtype: object

# %%
# 22. Display * of all females who survived.
df[(df.Survived == 1) & (df.Sex == 'female')]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2       1.0     1.0
# 2             3       1.0     3.0
# 3             4       1.0     1.0
# 8             9       1.0     3.0
# 9            10       1.0     2.0
# ..          ...       ...     ...
# 874         875       1.0     2.0
# 875         876       1.0     3.0
# 879         880       1.0     1.0
# 880         881       1.0     2.0
# 887         888       1.0     1.0
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0    0.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0    1.0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 23. Display * of all males, travelling in class I who Survived.
df[(df.Survived == 1) & (df.Sex == 'male') & (df.Pclass == 1)][['Name', 'Sex', 'Pclass', 'Survived']]
# Out:
#                                               Name   Sex  Pclass  Survived
# 23                    Sloper, Mr. William Thompson  male     1.0       1.0
# 55                               Woolner, Mr. Hugh  male     1.0       1.0
# 97                 Greenfield, Mr. William Bertram  male     1.0       1.0
# 187  Romaine, Mr. Charles Hallace ("Mr C Rolmane")  male     1.0       1.0
# 209                               Blank, Mr. Henry  male     1.0       1.0
# 224                   Hoyt, Mr. Frederick Maxfield  male     1.0       1.0
# 248                  Beckwith, Mr. Richard Leonard  male     1.0       1.0
# 298                          Saalfeld, Mr. Adolphe  male     1.0       1.0
# 305                 Allison, Master. Hudson Trevor  male     1.0       1.0
# 370                    Harder, Mr. George Achilles  male     1.0       1.0
# 390                     Carter, Mr. William Ernest  male     1.0       1.0
# ...

# %%
# 24. Display * of females with age >50 that survived.
df[(df.Age >= 30) & (df.Sex == 'female') & (df.Survived == 1)][['Name', 'Sex', 'Pclass', 'Survived']]
# Out:
#                                                   Name     Sex  Pclass  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female     1.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     1.0
# 11                            Bonnell, Miss. Elizabeth  female     1.0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female     2.0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female     3.0
# ..                                                 ...     ...     ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female     1.0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female     1.0
# 865                           Bystrom, Mrs. (Karolina)  female     2.0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female     1.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female     1.0
#
#      Survived
# 1         1.0
# 3         1.0
# 11        1.0
# 15        1.0
# 25        1.0
# ..        ...
# ...

# %%
# 25. Display Survival status of all passengers travelling in class I.
df[(df.Pclass == 1)][['Survived']].value_counts()
# Out:
# Survived
# 1.0         136
# 0.0          80
# Name: count, dtype: int64

# %%
# 26. Display Survival status of all passengers travelling in class II.
df[(df.Pclass == 2)][['Survived']].value_counts()
# Out:
# Survived
# 0.0         97
# 1.0         87
# Name: count, dtype: int64

# %%
# 27. Display Survival status of all passengers travelling in class III.
df[(df.Pclass == 2)][['Survived']].value_counts()
# Out:
# Survived
# 0.0         97
# 1.0         87
# Name: count, dtype: int64

# %%
# 28. Display Survival status of passengers who paid more than median fig of ticket.
df[df['Fare'] > df['Fare'].median()][['Survived']].value_counts()
# Out:
# Survived
# 1.0         230
# 0.0         214
# Name: count, dtype: int64

# %%
# 29. Display Sex wise Survival status of passengers.
df.groupby('Sex')['Survived'].value_counts().unstack()
# Out:
# Survived  0.0  1.0
# Sex
# female     81  233
# male      468  109

# %%
# 30. Display  passenger class, sex  wise survival status.
df.groupby(['Pclass', 'Sex'])['Survived'].value_counts()
# Out:
# Pclass  Sex     Survived
# 1.0     female  1.0          91
#                 0.0           3
#         male    0.0          77
#                 1.0          45
# 2.0     female  1.0          70
#                 0.0           6
#         male    0.0          91
#                 1.0          17
# 3.0     female  0.0          72
#                 1.0          72
#         male    0.0         300
#                 1.0          47
# Name: count, dtype: int64

# %%
# 31. Display Sex wise Survival status of passengers travelling with SibSp s.    SibSp > 0
df[df['SibSp'] > 0].groupby(['Sex', 'Survived'])['PassengerId'].count()
# Out:
# Sex     Survived
# female  0.0          44
#         1.0          96
# male    0.0         107
#         1.0          36
# Name: PassengerId, dtype: int64

# %%
# 32. Display class wise Survival status of passengers embarked at each class. 
df.groupby(['Pclass', 'Embarked', 'Survived'])['PassengerId'].count()
# Out:
# Pclass  Embarked                                         Survived
# 1.0     C                                                0.0          26
#                                                          1.0          59
#         Q                                                0.0           1
#                                                          1.0           1
#         S                                                0.0          53
#                                                          1.0          74
# 2.0     C                                                0.0           8
#                                                          1.0           9
#         Q                                                0.0           1
#                                                          1.0           2
#         S                                                0.0          88
#                                                          1.0          76
# ...

# %%
# 33. Display Sex wise survival status of passengers who paid more fare. 
#       A. Above Average.
#       B. Above III Quartile. [>= 75 Percentile]
#       C. Top 10%.


# A. Above Average
fare_avg = df['Fare'].mean()
above_avg = df[df['Fare'] > fare_avg].groupby(['Sex', 'Survived'])['PassengerId'].count()
print("Above Average Fare:\n", above_avg)

# B. Above III Quartile (>= 75th Percentile)
fare_75 = df['Fare'].quantile(0.75)
above_75 = df[df['Fare'] >= fare_75].groupby(['Sex', 'Survived'])['PassengerId'].count()
print("Above 75th Percentile Fare:\n", above_75)

# C. Top 10% 
fare_90 = df['Fare'].quantile(0.90)
top_10 = df[df['Fare'] >= fare_90].groupby(['Sex', 'Survived'])['PassengerId'].count()
print("Top 10% Fare:\n", top_10)
# Out:
# Above Average Fare:
#  Sex     Survived
# female  0.0         11
#         1.0         93
# male    0.0         74
#         1.0         33
# Name: PassengerId, dtype: int64
# Above 75th Percentile Fare:
#  Sex     Survived
# female  0.0         16
#         1.0         96
# male    0.0         78
#         1.0         35
# Name: PassengerId, dtype: int64
# Top 10% Fare:
#  Sex     Survived
# female  0.0          2
#         1.0         57
# male    0.0         19
#         1.0         12
# Name: PassengerId, dtype: int64

# %%
# Create a new column family_size by adding sibsp (siblings/spouses) and parch (parents/children) together.

df['family_size'] = df['SibSp'] + df['Parch']
df['family_size']
# Out:
# 0      1.0
# 1      1.0
# 2      0.0
# 3      1.0
# 4      0.0
#       ...
# 889    0.0
# 890    0.0
# 891    NaN
# 892    NaN
# 893    NaN
# Name: family_size, Length: 894, dtype: float64

# %%
# Find the survival rate of passengers who traveled alone (family_size = 0).
alone_passengers = df[df['family_size'] == 0]

# Calculate the survival rate
survival_rate_alone = alone_passengers['Survived'].mean()
survival_rate_alone
# Out:
# np.float64(0.30353817504655495)

# %%
# Find the probability of survival for passengers aged between 20 and 30.
young_adults = df[(df['Age'] >= 20) & (df['Age'] <= 30)]

# Calculate the survival rate
survival_rate_of_Young_Adults = young_adults['Survived'].mean()
survival_rate_of_Young_Adults
# Out:
# np.float64(0.3551020408163265)
